# %% [markdown]
# <a href="https://colab.research.google.com/github/raisyaac/Dasar-x-2627/blob/main/X_PPLG_Raisya_putri_Darmawan_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tugas 1 praktik membuat variabel variabel dan tipe data
#
# nama kelompok: nexacode
#
# 1. Raisya putri darmawan
# 2. nur mawadah
# 3. Syafira meidina Syarif
# 4. alyaa Rahma Thalita
# 5. Teuku Muhammad Fadhil
# 6. Davi Ramadhani Pratama
# 7. aghnan aiszar kamaludin

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
# // Deklarasi variabel dan tipe data
# string namabarang = "sepatu adidas";
# int jumlah = 2;
# float harga = 2900000.50;
# char kategori= 'A';
# bool tersedia = true;
#
# // menampilkan output ke layar
# cout << "=== Data inventaris===" << endl;
# cout << "namabarang : " << namabarang << endl;
# cout << "kategori : " << kategori << endl;
# cout << "jumlah : " << jumlah << endl;
# cout << "harga : Rp " << harga << endl;
# cout << "tersedia : " << tersedia << " (1 = ya, 0= tidak)" << endl;
# cout << "=====================" <<
# endl;
# return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
! ./praktik_variabel
# Out:
# === Data inventaris===
# namabarang : sepatu adidas
# kategori : A
# jumlah : 2
# harga : Rp 2.9e+06
# tersedia : 1 (1 = ya, 0= tidak)
# ...
